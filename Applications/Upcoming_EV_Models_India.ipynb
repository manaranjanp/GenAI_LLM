# %% [markdown]
# # Information Extraction
#
# **Author**: Manaranjan Pradhan <br/>
# www.manaranjanp.com

# %%
# !pip install -q langchain openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.7/223.7 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.

# %% [markdown]
# [Source: Washington Post](https://www.washingtonpost.com/climate-environment/2023/04/11/electric-vehicle-buying-guide/)

# %% [markdown]
# ## Accesing the Page Content

# %%
import requests

# %%
url = "https://www.zigwheels.com/newcars/electric-cars"

# %%
from bs4 import BeautifulSoup

html = requests.get(url).text
soup = BeautifulSoup(html)
text = soup.get_text()

# %%
print(text[0:1000])
# Out:
# Electric Cars in India, EV Car Prices, Mileage, Battery Cars @ ZigWheels
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rvmp_make,rvmp_forum_ask_car_owner,rvmp_question_box,rvmp_running_cost_form,rvmp_story_script,rvmp_running_cost_form
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# News & Reviews
#
# Auto News
# Expert Reviews
# User Reviews
# Ask a Question
# Auto Visual Stories
# Photo Gallery
# Video Gallery
#
#
#
# New Cars
#
# Find New Cars
#
#
# Popular Car Brands
#
#  Renault Cars
#  Skoda Cars
#  Jeep Cars
#  Citroen Cars
#  Hyundai Cars
#  Tata Cars
#  Maruti Suzuki Cars
#  Kia Cars
#  Mahindra Cars
#  Toyota Cars
#  Honda Cars
#  MG Cars
#  All Car Brands
#
#
#
# Popular Car Models
#
#  Maruti Grand Vitara
#  Renault Kiger
#  Skoda Slavia
#  Tata Punch
#  Hyundai Exter
#  Maruti FRONX
#  Maruti Swift
#  Jeep Wrangler
#  Jeep Compass
#  Hyundai Creta
#  Kia Sonet
#  Mahindra Thar
#  Volkswagen Tiguan
#  Mahindra Scorpio N
#  Toyota Innova Hycross
#  Best Cars in India
#
#
#
# Cars By Budget
#
#  Cars Under 5 Lakhs
#  Cars Under 8 Lakhs
#  Cars Under 10 Lakhs
#  Cars Under 15

# %%
beginning = 'Popular Electric Cars in 2023'
ending = "Key Highlights of Electric Cars"
final_text = text[text.index(beginning):text.index(ending)]
final_text = final_text.replace("\n", "\t")

# %%
print(final_text)
# Out:
# Popular Electric Cars in 2023							3.3	|  39 reviews					Tata Nexon EV			Rs. 14.74 Lakh		Check On-Road Price »	30 kWh | 95 kW | 465 km/charge	View December Offers									4	|  52 reviews					Kia EV6			Rs. 60.95 Lakh		Check On-Road Price »	77.4 kWh | 708 km/charge | 192 km/h	View December Offers									4.6	|  144 reviews					Tata Tiago EV			Rs. 8.69 Lakh		Check On-Road Price »	24 KWh | 45 kW | 315 km/charge	View December Offers									5	|  20 reviews					BMW i7			Rs. 2.03 Crore		Check On-Road Price »	101.7kWh | 400 kW | 625 km/charge	View December Offers									4.4	|  94 reviews					Mahindra XUV400 EV			Rs. 15.99 Lakh		Check On-Road Price »	34.5 kWh | 100 kW | 456 km/charge	View December Offers									3.6	|  74 reviews					MG Comet EV			Rs. 7.98 Lakh		Check On-Road Price »	17.3 kWh | 40.14bhp | 230 km/charge	View December Offers									4.2	|  24 reviews					BMW iX			Rs. 1.21 Crore		Check On-Road Price »	71 kW | 240 kW | 425 km/charge	View December Offers									4.8	|  51 reviews					Tata Tigor EV			Rs. 12.49 Lakh		Check On-Road Price »	26 kWh | 315 km/charge | 120 km/h	View December Offers									4	|  51 reviews					Hyundai Kona Electric			Rs. 23.84 Lakh		Check On-Road Price »	39.2 kWh | 100 kW | 452 km/charge	View December Offers									4.2	|  51 reviews					MG ZS EV			Rs. 22.88 Lakh		Check On-Road Price »	50.3 kWh | 129 kW | 461 km/charge	View December Offers									4.1	|  32 reviews					BMW i4			Rs. 72.50 Lakh		Check On-Road Price »	70.2kWh | 210 kW | 590 km/charge	View December Offers											Lotus Eletre			Rs. 2.55 Crore		Check On-Road Price »	112 kwh | 450 | 600 km/charge	View December Offers									4.1	|  49 reviews					BYD Atto 3			Rs. 33.99 Lakh		Check On-Road Price »	60.48 kWh | 150 kW | 521 km/charge	View December Offers									4.6	|  52 reviews					BYD E6			Rs. 29.15 Lakh		Check On-Road Price »	71.7 kWh | 70 kW | 415 km/charge	View December Offers									4.7	|  11 reviews					Mercedes-Benz EQS			Rs. 1.62 Crore		Check On-Road Price »	107.8 kwh | 857 km/charge | 210 km/h	Contact Dealer									4	|  24 reviews					Audi e-tron			Rs. 1.02 Crore		Check On-Road Price »	95kwh | 300 kW | 484 km/charge	View December Offers									4.4	|  45 reviews					Citroen eC3			Rs. 11.61 Lakh		Check On-Road Price »	29.2 kWh | 42 kW | 320 km/charge	View December Offers									4.2	|  19 reviews					Jaguar I-Pace			Rs. 1.19 Crore		Check On-Road Price »	90 kWh | 294 kW | 470 km/charge	View December Offers									4.8	|  read reviews					Porsche Taycan			Rs. 1.60 Crore		Check On-Road Price »	93.4 | 560 kW | 395 km/charge	View December Offers									1	|  12 reviews					PMV EaS E			Rs. 4.79 Lakh		Check On-Road Price »	10kWh | 160 km/charge | 70 km/h	View December Offers									5	|  read reviews					Audi RS e-tron GT			Rs. 1.93 Crore		Check On-Road Price »	93 kWh | 475 kW | 401 km/charge	View December Offers									4.8	|  24 reviews					Audi e-tron GT			Rs. 1.70 Crore		Check On-Road Price »	93 kWh | 390 kW | 388 km/charge	View December Offers									4	|  27 reviews					Volvo XC40 Recharge			Rs. 56.90 Lakh		Check On-Road Price »	78 kW | 402.41 bhp | 418 km/charge	View December Offers									4.7	|  19 reviews					Strom Motors R3			Rs. 4.50 Lakh		Check On-Road Price »	15 kW | 200 km/charge | 80 km/h	View December Offers									2.6	|  32 reviews					Mini Cooper SE			Rs. 53.50 Lakh		Check On-Road Price »	32.6 KwH | 135 kW | 270 km/charge	View December Offers									4.6	|  12 reviews					Hyundai IONIQ 5			Rs. 45.95 Lakh		Check On-Road Price »	72.6 kWh | 160 kW | 631 km/charge	View December Offers									5	|  read reviews					BMW iX1			Rs. 66.90 Lakh		Check On-Road Price »	66.4 kwh | 230 kW | 417 km/charge	View December Offers									4.7	|  read reviews					Volvo C40 Recharge			Rs. 62.95 Lakh		Check On-Road Price »	78kWh | 402.30 | 530 km/charge	View December Offers									4.8	|  25 reviews					Mercedes-Benz EQB			Rs. 74.50 Lakh		Check On-Road Price »	66.5Kwh | 423 km/charge | 160 km/h	Contact Dealer											Mercedes-Benz EQ ...

# %%
len(final_text)
# Out:
# 4630

# %% [markdown]
# ### Storing the page content in file

# %%
with open("ev_article.txt", "w") as f:
    f.write(final_text)

# %% [markdown]
# ### Libararies or components used.
#
# - OpenAI (https://platform.openai.com/)
# - LangChain (https://langchain.com/)

# %% [markdown]
# ## Configuring LLM for Query

# %%
import os
import openai
from getpass import getpass
from pprint import pprint

# %%
os.environ['OPENAI_API_KEY'] = getpass("OpenAI Key:")
# Out:
# OpenAI Key:··········

# %%
openai.api_key  = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ### Initializing the OpenAI Chat Model

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import create_extraction_chain, create_extraction_chain_pydantic
from langchain.prompts import ChatPromptTemplate

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains.conversation.memory import ConversationBufferWindowMemory
from langchain.chains import RetrievalQA

# chat completion llm
llm = ChatOpenAI(
    model_name='gpt-3.5-turbo-0613',
    temperature=0.0
)

# %% [markdown]
# ### Configuring the Retrieval QA Chain
#
# https://json-schema.org/understanding-json-schema/

# %%
schema = {
    "properties": {
        "model_name": {"type": "string"},
        "price": {"type": "string"},
        "range_kms": {"type": "integer"},
        "battery_capacity": {"type": "integer"},
    },
    "required": ["model_name", "price", "range_kms"],
}

# %% [markdown]
# ### Configurating Conversational Memory

# %%
chain = create_extraction_chain(schema, llm)

# %%
print(chain.prompt.messages[0])
# Out:
# prompt=PromptTemplate(input_variables=['input'], template="Extract and save the relevant entities mentioned in the following passage together with their properties.\n\nOnly extract the properties mentioned in the 'information_extraction' function.\n\nIf a property is not present and is not required in the function parameters, do not include it in the output.\n\nPassage:\n{input}\n")

# %%
print(chain.prompt.messages[0].prompt.template)
# Out:
# Extract and save the relevant entities mentioned in the following passage together with their properties.
#
# Only extract the properties mentioned in the 'information_extraction' function.
#
# If a property is not present and is not required in the function parameters, do not include it in the output.
#
# Passage:
# {input}

# %%
chain.llm_kwargs
# Out:
# {'functions': [{'name': 'information_extraction',
#    'description': 'Extracts the relevant information from the passage.',
#    'parameters': {'type': 'object',
#     'properties': {'info': {'type': 'array',
#       'items': {'type': 'object',
#        'properties': {'model_name': {'title': 'model_name', 'type': 'string'},
#         'price': {'title': 'price', 'type': 'string'},
#         'range_kms': {'title': 'range_kms', 'type': 'integer'},
#         'battery_capacity': {'title': 'battery_capacity', 'type': 'integer'}},
#        'required': ['model_name', 'price', 'range_kms']}}},
#     'required': ['info']}}],
#  'function_call': {'name': 'information_extraction'}}

# %% [markdown]
# ## Asking Questions

# %%
response = chain.run(final_text)
response
# Out:
# [{'model_name': 'Tata Tiago EV',
#   'price': 'Rs. 8.69 Lakh',
#   'range_kms': 315,
#   'battery_capacity': 19.2},
#  {'model_name': 'MG Comet EV',
#   'price': 'Rs. 7.98 Lakh',
#   'range_kms': 230,
#   'battery_capacity': 17.3},
#  {'model_name': 'Kia EV6',
#   'price': 'Rs. 60.95 Lakh',
#   'range_kms': 708,
#   'battery_capacity': 77.4},
#  {'model_name': 'BMW i4',
#   'price': 'Rs. 72.50 Lakh',
#   'range_kms': 590,
#   'battery_capacity': 70.2},
#  {'model_name': 'BMW i7',
#   'price': 'Rs. 1.95 Crore',
#   'range_kms': 590,
#   'battery_capacity': 101.7},
#  {'model_name': 'Tata Tigor EV',
#   'price': 'Rs. 12.49 Lakh',
#   'range_kms': 315,
#   'battery_capacity': 26},
#  {'model_name': 'BMW iX',
#   'price': 'Rs. 1.21 Crore',
#   'range_kms': 372,
#   'battery_capacity': 71},
#  {'model_name': 'MG ZS EV',
#   'price': 'Rs. 23.38 Lakh',
#   'range_kms': 461,
#   'battery_capacity': 50.3},
#  {'model_name': 'Hyundai Kona Electric',
#   'price': 'Rs. 23.84 Lakh',
#   'range_kms': 452,
#   'battery_capacity': 39.2},
#  {'model_name': 'Audi e-tron GT',
#   'price': 'Rs. 1.70 Crore',
#   'range_kms': 388,
#   'battery_capacity': 93.4},
#  {'model_name': 'Mercedes-Benz EQS',
#   'price': 'Rs. 1.59 Crore',
#   'range_kms': 857,
#   'battery_capacity': 107.8},
#  {'model_name': 'BYD Atto 3',
#   'price': 'Rs. 33.99 Lakh',
#   'range_kms': 521,
#   'battery_capacity': 60.48},
#  {'model_name': 'Mahindra XUV400 EV',
#   'price': 'Rs. 15.98 Lakh',
#   'range_kms': 456,
#   'battery_capacity': 34.5},
#  {'model_name': 'BMW iX1',
#   'price': 'Rs. 66.90 Lakh',
#   'range_kms': 417,
#   'battery_capacity': 66.4},
#  {'model_name': 'Audi e-tron',
#   'price': 'Rs. 1.02 Crore',
#   'range_kms': 359,
#   'battery_capacity': 95},
#  {'model_name': 'BYD E6',
#   'price': 'Rs. 29.15 Lakh',
#   'range_kms': 415,
#   'battery_capacity': 71.7},
#  {'model_name': 'Citroen eC3',
#   'price': 'Rs. 11.50 Lakh',
#   'range_kms': 320,
#   'battery_capacity': 29.2},
#  {'model_name': 'Jaguar I-Pace',
#   'price': 'Rs. 1.19 Crore',
#   'range_kms': 446,
#   'battery_capacity': 90},
#  {'model_name': 'Porsche Taycan',
#   'price': 'Rs. 1.60 Crore',
#   'range_kms': 395,
#   'battery_capacity': 93.4},
#  {'model_name': 'Mercedes-Benz EQE SUV',
#   'price': 'Rs. 1.39 Crore',
#   'range_kms': 550,
#   'battery_capacity': 90.56},
#  {'model_name': 'Volvo C40 Recharge',
#   'price': 'Rs. 61.25 Lakh',
#   'range_kms': 530,
#   'battery_capacity': 78},
#  {'model_name': 'PMV EaS E',
#   'price': 'Rs. 4.79 Lakh',
#   'range_kms': 160,
#   'battery_capacity': 10},
#  {'model_name': 'Audi RS e-tron GT',
#   'price': 'Rs. 1.93 Crore',
#   'range_kms': 401,
#   'battery_capacity': 93.4},
#  {'model_name': 'Strom Motors R3',
#   'price': 'Rs. 4.50 Lakh',
#   'range_kms': 200,
#   'battery_capacity': None},
#  {'model_name': 'Volvo XC40 Recharge',
#   'price': 'Rs. 56.90 Lakh',
#   'range_kms': 418,
#   'battery_capacity': 78},
#  {'model_name': 'Mini Cooper SE',
#   'price': 'Rs. 53.50 Lakh',
#   'range_kms': 270,
#   'battery_capacity': 32.6},
#  {'model_name': 'Hyundai IONIQ 5',
#   'price': 'Rs. 45.95 Lakh',
#   'range_kms': 631,
#   'battery_capacity': 72.6},
#  {'model_name': 'Mercedes-Benz EQB',
#   'price': 'Rs. 77.50 Lakh',
#   'range_kms': 423,
#   'battery_capacity': 66.5},
#  {'model_name': 'Audi Q8 e-tron',
#   'price': 'Rs. 1.13 Crore',
#   'range_kms': 582,
#   'battery_capacity': 114},
#  {'model_name': 'Pravaig DEFY',
#   'price': 'Rs. 39.50 Lakh',
#   'range_kms': 500,
#   'battery_capacity': 90},
#  {'model_name': 'Tata Nexon EV',
#   'price': 'Rs. 14.74 Lakh',
#   'range_kms': 465,
#   'battery_capacity': 30},
#  {'model_name': 'Mercedes-Benz AMG EQS',
#   'price': 'Rs. 2.45 Crore',
#   'range_kms': 526,
#   'battery_capacity': 107.8},
#  {'model_name': 'Audi Q8 Sportback e-tron',
#   'price': 'Rs. 1.18 Crore',
#   'range_kms': 600,
#   'battery_capacity': 95}]

# %%
type(response)
# Out:
# list

# %% [markdown]
# ### To buy or to wait

# %%
import pandas as pd
import json

# %%
ev_df = pd.read_json(json.dumps(response))

# %%
ev_df
# Out:
#                   model_name           price  range_kms  battery_capacity
# 0              Tata Tiago EV   Rs. 8.69 Lakh        315             19.20
# 1                MG Comet EV   Rs. 7.98 Lakh        230             17.30
# 2                    Kia EV6  Rs. 60.95 Lakh        708             77.40
# 3                     BMW i4  Rs. 72.50 Lakh        590             70.20
# 4                     BMW i7  Rs. 1.95 Crore        590            101.70
# 5              Tata Tigor EV  Rs. 12.49 Lakh        315             26.00
# 6                     BMW iX  Rs. 1.21 Crore        372             71.00
# 7                   MG ZS EV  Rs. 23.38 Lakh        461             50.30
# 8      Hyundai Kona Electric  Rs. 23.84 Lakh        452             39.20
# 9             Audi e-tron GT  Rs. 1.70 Crore        388             93.40
# 10         Mercedes-Benz EQS  Rs. 1.59 Crore        857            107.80
# 11                BYD Atto 3  Rs. 33.99 Lakh        521             60.48
# 12        Mahindra XUV400 EV  Rs. 15.98 Lakh        456             34.50
# 13                   BMW iX1  Rs. 66.90 Lakh        417             66.40
# 14               Audi e-tron  Rs. 1.02 Crore        359             95.00
# 15                    BYD E6  Rs. 29.15 Lakh        415             71.70
# 16               Citroen eC3  Rs. 11.50 Lakh        320             29.20
# 17             Jaguar I-Pace  Rs. 1.19 Crore        446             90.00
# 18            Porsche Taycan  Rs. 1.60 Crore        395             93.40
# 19     Mercedes-Benz EQE SUV  Rs. 1.39 Crore        550             90.56
# 20        Volvo C40 Recharge  Rs. 61.25 Lakh        530             78.00
# 21                 PMV EaS E   Rs. 4.79 Lakh        160             10.00
# 22         Audi RS e-tron GT  Rs. 1.93 Crore        401             93.40
# 23           Strom Motors R3   Rs. 4.50 Lakh        200               NaN
# 24       Volvo XC40 Recharge  Rs. 56.90 Lakh        418             78.00
# 25            Mini Cooper SE  Rs. 53.50 Lakh        270             32.60
# 26           Hyundai IONIQ 5  Rs. 45.95 Lakh        631             72.60
# 27         Mercedes-Benz EQB  Rs. 77.50 Lakh        423             66.50
# 28            Audi Q8 e-tron  Rs. 1.13 Crore        582            114.00
# 29              Pravaig DEFY  Rs. 39.50 Lakh        500             90.00
# 30             Tata Nexon EV  Rs. 14.74 Lakh        465             30.00
# 31     Mercedes-Benz AMG EQS  Rs. 2.45 Crore        526            107.80
# 32  Audi Q8 Sportback e-tron  Rs. 1.18 Crore        600             95.00

# %%
ev_df['price_lakhs'] = ev_df.price.map(lambda x: (float(x.split(" ")[1])*100
                                                if 'crore' in (x.split(" ")[2].lower())
                                                else float(x.split(" ")[1])))

# %%
ev_df['make'] = ev_df.model_name.map(lambda x: x.split()[0])

# %%
ev_df[0:10]
# Out:
#               model_name           price  range_kms  battery_capacity  \
# 0          Tata Tiago EV   Rs. 8.69 Lakh        315              19.2
# 1            MG Comet EV   Rs. 7.98 Lakh        230              17.3
# 2                Kia EV6  Rs. 60.95 Lakh        708              77.4
# 3                 BMW i4  Rs. 72.50 Lakh        590              70.2
# 4                 BMW i7  Rs. 1.95 Crore        590             101.7
# 5          Tata Tigor EV  Rs. 12.49 Lakh        315              26.0
# 6                 BMW iX  Rs. 1.21 Crore        372              71.0
# 7               MG ZS EV  Rs. 23.38 Lakh        461              50.3
# 8  Hyundai Kona Electric  Rs. 23.84 Lakh        452              39.2
# 9         Audi e-tron GT  Rs. 1.70 Crore        388              93.4
#
#    price_lakhs     make
# 0         8.69     Tata
# 1         7.98       MG
# 2        60.95      Kia
# 3        72.50      BMW
# 4       195.00      BMW
# 5        12.49     Tata
# 6       121.00      BMW
# 7        23.38       MG
# 8        23.84  Hyundai
# 9       170.00     Audi

# %%
ev_df.to_csv('ev_models.csv', index = False)

# %% [markdown]
# ## Using Pydantic
#
# https://docs.pydantic.dev/latest/
#
# ```
# schema = {
#     "properties": {
#         "model_name": {"type": "string"},
#         "price": {"type": "string"},
#         "range_kms": {"type": "integer"},
#         "battery_capacity": {"type": "integer"},
#     },
#     "required": ["person_name", "price_lakhs", "range_kms"],
# }
#
# ```

# %%
from typing import Optional, List
from pydantic import BaseModel, Field
from langchain.chains import create_extraction_chain_pydantic

# %%
# Pydantic data class
class Properties(BaseModel):
    model_name: str = Field(description="The name of the EV model")
    price: str = Field(description="Price of the model in lakhs (Indian Rupees)")
    range_kms: int = Field(description="Kilometers it would travel aftera single full charge")
    battery_capacity: Optional[int] = Field(description="Battery Capacity of the model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-72eb5611a684> in <cell line: 2>()
#       1 # Pydantic data class
# ----> 2 class Properties(BaseModel):
#       3     model_name: str = Field(description="The name of the EV model")
#       4     price: str = Field(description="Price of the model in lakhs (Indian Rupees)")
#       5     range_kms: int = Field(description="Kilometers it would travel aftera single full charge")
#
# NameError: name 'BaseModel' is not defined

# %%
chain = create_extraction_chain_pydantic(pydantic_schema=Properties, llm=llm)

# %%
pprint(print(chain.prompt.messages[0].prompt.template))
# Out:
# Extract and save the relevant entities mentionedin the following passage together with their properties.
#
# Only extract the properties mentioned in the 'information_extraction' function.
#
# If a property is not present and is not required in the function parameters, do not include it in the output.
#
# Passage:
# {input}
#
# None

# %%
chain.llm_kwargs
# Out:
# {'functions': [{'name': 'information_extraction',
#    'description': 'Extracts the relevant information from the passage.',
#    'parameters': {'type': 'object',
#     'properties': {'info': {'type': 'array',
#       'items': {'type': 'object',
#        'properties': {'model_name': {'title': 'Model Name',
#          'description': 'The name of the EV model',
#          'type': 'string'},
#         'price': {'title': 'Price',
#          'description': 'Price of the model in lakhs (Indian Rupees)',
#          'type': 'string'},
#         'range_kms': {'title': 'Range Kms',
#          'description': 'Kilometers it would travel aftera single full charge',
#          'type': 'integer'},
#         'battery_capacity': {'title': 'Battery Capacity',
#          'description': 'Battery Capacity of the model',
#          'type': 'integer'}},
#        'required': ['model_name', 'price', 'range_kms']}}},
#     'required': ['info']}}],
#  'function_call': {'name': 'information_extraction'}}

# %%
response = chain.run(final_text)
response
# Out:
# [Properties(model_name='Tata Tiago EV', price='Rs. 8.69 Lakh', range_kms=315, battery_capacity=19),
#  Properties(model_name='MG Comet EV', price='Rs. 7.98 Lakh', range_kms=230, battery_capacity=17),
#  Properties(model_name='Kia EV6', price='Rs. 60.95 Lakh', range_kms=708, battery_capacity=77),
#  Properties(model_name='BMW i4', price='Rs. 72.50 Lakh', range_kms=590, battery_capacity=70),
#  Properties(model_name='BMW i7', price='Rs. 1.95 Crore', range_kms=590, battery_capacity=101),
#  Properties(model_name='Tata Tigor EV', price='Rs. 12.49 Lakh', range_kms=315, battery_capacity=26),
#  Properties(model_name='BMW iX', price='Rs. 1.21 Crore', range_kms=372, battery_capacity=71),
#  Properties(model_name='MG ZS EV', price='Rs. 23.38 Lakh', range_kms=461, battery_capacity=50),
#  Properties(model_name='Hyundai Kona Electric', price='Rs. 23.84 Lakh', range_kms=452, battery_capacity=39),
#  Properties(model_name='Audi e-tron GT', price='Rs. 1.70 Crore', range_kms=388, battery_capacity=93),
#  Properties(model_name='Mercedes-Benz EQS', price='Rs. 1.59 Crore', range_kms=857, battery_capacity=107),
#  Properties(model_name='BYD Atto 3', price='Rs. 33.99 Lakh', range_kms=521, battery_capacity=60),
#  Properties(model_name='Mahindra XUV400 EV', price='Rs. 15.98 Lakh', range_kms=456, battery_capacity=34),
#  Properties(model_name='BMW iX1', price='Rs. 66.90 Lakh', range_kms=417, battery_capacity=66),
#  Properties(model_name='Audi e-tron', price='Rs. 1.02 Crore', range_kms=359, battery_capacity=95),
#  Properties(model_name='BYD E6', price='Rs. 29.15 Lakh', range_kms=415, battery_capacity=71),
#  Properties(model_name='Citroen eC3', price='Rs. 11.50 Lakh', range_kms=320, battery_capacity=29),
#  Properties(model_name='Jaguar I-Pace', price='Rs. 1.19 Crore', range_kms=446, battery_capacity=90),
#  Properties(model_name='Porsche Taycan', price='Rs. 1.60 Crore', range_kms=395, battery_capacity=93),
#  Properties(model_name='Mercedes-Benz EQE SUV', price='Rs. 1.39 Crore', range_kms=550, battery_capacity=90),
#  Properties(model_name='Volvo C40 Recharge', price='Rs. 61.25 Lakh', range_kms=530, battery_capacity=78),
#  Properties(model_name='PMV EaS E', price='Rs. 4.79 Lakh', range_kms=160, battery_capacity=10),
#  Properties(model_name='Audi RS e-tron GT', price='Rs. 1.93 Crore', range_kms=401, battery_capacity=93),
#  Properties(model_name='Strom Motors R3', price='Rs. 4.50 Lakh', range_kms=200, battery_capacity=None),
#  Properties(model_name='Volvo XC40 Recharge', price='Rs. 56.90 Lakh', range_kms=418, battery_capacity=78),
#  Properties(model_name='Mini Cooper SE', price='Rs. 53.50 Lakh', range_kms=270, battery_capacity=32),
#  Properties(model_name='Hyundai IONIQ 5', price='Rs. 45.95 Lakh', range_kms=631, battery_capacity=72),
#  Properties(model_name='Mercedes-Benz EQB', price='Rs. 77.50 Lakh', range_kms=423, battery_capacity=66),
#  Properties(model_name='Audi Q8 e-tron', price='Rs. 1.13 Crore', range_kms=582, battery_capacity=114),
#  Properties(model_name='Pravaig DEFY', price='Rs. 39.50 Lakh', range_kms=500, battery_capacity=90),
#  Properties(model_name='Tata Nexon EV', price='Rs. 14.74 Lakh', range_kms=465, battery_capacity=30),
#  Properties(model_name='Mercedes-Benz AMG EQS', price='Rs. 2.45 Crore', range_kms=526, battery_capacity=107),
#  Properties(model_name='Audi Q8 Sportback e-tron', price='Rs. 1.18 Crore', range_kms=600, battery_capacity=95)]

# %%
pd.DataFrame([(x.model_name, x.price, x.range_kms, x.battery_capacity) for x in response])
# Out:
#                            0               1    2      3
# 0              Tata Tiago EV   Rs. 8.69 Lakh  315   19.0
# 1                MG Comet EV   Rs. 7.98 Lakh  230   17.0
# 2                    Kia EV6  Rs. 60.95 Lakh  708   77.0
# 3                     BMW i4  Rs. 72.50 Lakh  590   70.0
# 4                     BMW i7  Rs. 1.95 Crore  590  101.0
# 5              Tata Tigor EV  Rs. 12.49 Lakh  315   26.0
# 6                     BMW iX  Rs. 1.21 Crore  372   71.0
# 7                   MG ZS EV  Rs. 23.38 Lakh  461   50.0
# 8      Hyundai Kona Electric  Rs. 23.84 Lakh  452   39.0
# 9             Audi e-tron GT  Rs. 1.70 Crore  388   93.0
# 10         Mercedes-Benz EQS  Rs. 1.59 Crore  857  107.0
# 11                BYD Atto 3  Rs. 33.99 Lakh  521   60.0
# 12        Mahindra XUV400 EV  Rs. 15.98 Lakh  456   34.0
# 13                   BMW iX1  Rs. 66.90 Lakh  417   66.0
# 14               Audi e-tron  Rs. 1.02 Crore  359   95.0
# 15                    BYD E6  Rs. 29.15 Lakh  415   71.0
# 16               Citroen eC3  Rs. 11.50 Lakh  320   29.0
# 17             Jaguar I-Pace  Rs. 1.19 Crore  446   90.0
# 18            Porsche Taycan  Rs. 1.60 Crore  395   93.0
# 19     Mercedes-Benz EQE SUV  Rs. 1.39 Crore  550   90.0
# 20        Volvo C40 Recharge  Rs. 61.25 Lakh  530   78.0
# 21                 PMV EaS E   Rs. 4.79 Lakh  160   10.0
# 22         Audi RS e-tron GT  Rs. 1.93 Crore  401   93.0
# 23           Strom Motors R3   Rs. 4.50 Lakh  200    NaN
# 24       Volvo XC40 Recharge  Rs. 56.90 Lakh  418   78.0
# 25            Mini Cooper SE  Rs. 53.50 Lakh  270   32.0
# 26           Hyundai IONIQ 5  Rs. 45.95 Lakh  631   72.0
# 27         Mercedes-Benz EQB  Rs. 77.50 Lakh  423   66.0
# 28            Audi Q8 e-tron  Rs. 1.13 Crore  582  114.0
# 29              Pravaig DEFY  Rs. 39.50 Lakh  500   90.0
# 30             Tata Nexon EV  Rs. 14.74 Lakh  465   30.0
# 31     Mercedes-Benz AMG EQS  Rs. 2.45 Crore  526  107.0
# 32  Audi Q8 Sportback e-tron  Rs. 1.18 Crore  600   95.0
